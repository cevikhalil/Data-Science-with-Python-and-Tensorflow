# %% [markdown]
# Immutability & Mutable

# %%
myString = "Madeline Miller"
myString[0]
# Out:
# 'M'

# %%
myList = [10,20,30,40]
type(myList)
# Out:
# list

# %%
myList[1]
# Out:
# 20

# %%
myList.append(50)
myList
# Out:
# [10, 20, 30, 40, 50]

# %%
myList.count(30)
# Out:
# 1
