# %%
def firstFunction():
  print("This is my first function")

# %%
firstFunction()
# Out:
# This is my first function

# %%
def sum(num1,num2):
  result = num1 + num2
  print(result)

# %%
sum(-14,10)
# Out:
# -4

# %% [markdown]
# Args & Kwargs

# %%
def summation(*args):
  return sum(args)

# %%
summation(3,4,5,6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-bb5d938b5d08> in <module>()
# ----> 1 summation(3,4,5,6)
#
# <ipython-input-7-b915c0a7e635> in summation(*args)
#       1 def summation(*args):
# ----> 2   return sum(args)
#
# TypeError: sum() missing 1 required positional argument: 'num2'
