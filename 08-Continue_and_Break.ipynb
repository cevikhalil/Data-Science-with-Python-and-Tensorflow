# %%
myList = [4,8,12,16,2,24,28,32]

for num in myList:
  if num == 2:
    break
  print(num)
# Out:
# 4
# 8
# 12
# 16

# %%
myList = [4,8,12,16,2,24,28,32]

for num in myList:
  if num == 2:
    continue
  print(num)
# Out:
# 4
# 8
# 12
# 16
# 24
# 28
# 32
