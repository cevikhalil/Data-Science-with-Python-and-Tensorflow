# %%
myList = [1,2,3,1,2,3]
myList[0]
# Out:
# 1

# %%
myListSet = set(myList)
type(myListSet)
# Out:
# set

# %%
myListSet
# Out:
# {1, 2, 3}

# %%
mySet = {"a", "b", "c","a", "a"}
type(mySet)
# Out:
# set

# %%
mySet
# Out:
# {'a', 'b', 'c'}

# %%
emptyList = [] # creating an empty list
print(type(emptyList))
print(emptyList)
# Out:
# <class 'list'>
# []

# %%
emptySet = {} # creating an empty set
type(emptySet) # but type is dict (this is a problem)
# Out:
# dict

# %%
myEmptySet = set()
print(myEmptySet)
myEmptySet.add(10)
print(myEmptySet)
myEmptySet.add(10)
print(myEmptySet)
myEmptySet.add(20)
print(myEmptySet)
# Out:
# set()
# {10}
# {10}
# {10, 20}
